# %% [markdown]
# # 간단한 전이학습 해보기
#
# 1. 주제를 정한다.
# 2. 주제에 맞는 태스크를 판단한다.
# 3. 해당 태스크를 수행하는 모델을 huggingface에서 찾는다.
# 4. NSMC같은 적당한 데이터셋을 정제하여 준비한다.
# 5. 3에서 찾은 모델을 로드하여 '간단하게' 전이학습을 진행한다.
# 6. 추론 결과를 확인한다.

# %% [markdown]
# 문화유산 유적 3D 데이터를 활용한 텍스트 기반 유적 이미지 검색 모델
