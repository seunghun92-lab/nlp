# %% [markdown]
# # 워드 클라우드 (word cloud)
#
# - 목적/용도: 문서/리뷰/뉴스에서 자주 등장하는 키워드를 한눈에 파악하는 “탐색(EDA)용 요약 시각화”
# - 빈도 vs 중요도: 단순 빈도 외에도 TF-IDF(문서 내 중요도) 같은 가중치를 크기로 쓸 수 있음
# - 전처리에서 특히 중요한 것
#     - 불용어(조사/관사) 제거 + 표제어/어간 통일(예: kept/keep)
#     - 필요하면 n-gram(예: ‘고객 이탈’, ‘머신 러닝’) 도 단어처럼 묶어서 표현
# - 주의점(해석): 크기는 “많이 나온 정도”일 뿐이라 긍/부정, 문맥, 원인을 직접 말해주진 않음 → 다른 분석(감성/토픽 등)과 같이 보는 게 좋음
# - 옵션 팁: 마스크 이미지 적용(형태 지정), max_words, min_freq, 색상/폰트(한글은 폰트 지정 필요)로 가독성 조절 가능
#
# 1. 텍스트 전처리
# 2. 단어 빈도 계산
# 3. 단어 크기 결정
# 4. 단어 배치
# 5. 시각화

# %% [markdown]
# ### 데이터 준비

# %%
# https://drive.google.com/file/d/1yXNdduc6iAxtZo0BMuGDttVW7A90mFQ-/view?usp=sharing

import gdown                                                 # 구글 드라이브 파일은 파이썬에서 내려받는 라이브러리

id = '1yXNdduc6iAxtZo0BMuGDttVW7A90mFQ-'                     # gdown이 다운로드 가능한 direct URL
url = f"https://drive.google.com/uc?id={id}"                 # 저장할 로컬 파일명 
output = 'sms_spam.csv'

gdown.download(url, output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yXNdduc6iAxtZo0BMuGDttVW7A90mFQ-
# To: c:\nlp\02_preprocessing\sms_spam.csv
# 100%|██████████| 33.7M/33.7M [00:01<00:00, 19.4MB/s]
# 'sms_spam.csv'

# %%
import numpy as np
import pandas as pd
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
spam_df = pd.read_csv('sms_spam.csv')
spam_df
# Out:
#           SEQ                                                 CN
# 0      842298  [Web발신]ifg@(광고)[한음대리점 율량점] 류태자 단골고객님ifg@ifg@마지...
# 1      842299  [Web발신]ifg@(광고)[전자랜드중동점]ifg@최은순 고객님!ifg@전자랜드 *...
# 2      842300  제목 : (광고)현대미아점 통합ifg@▶*O,OOO원할인권◀도착ifg@현대미아 설화...
# 3      842301  [Web발신]ifg@(광고) 신세계면세점 명동점ifg@ifg@본 문자 수신 고객님께...
# 4      842302  [Web발신]ifg@(광고) 롯데마트 소중한 집사의 통장을 지켜라! 멍이도 냥이도 ...
# ...       ...                                                ...
# 29583  871887  [국제발신]ifg@저한국에가는데 친구가 당신이공항에마중나올시간이있다고 했어요, 제L...
# 29584  871888  [Web발신]ifg@(광고) 루이까스텔 인천구월*ifg@★루이까스텔 인천구월점★if...
# 29585  871889  [국제발신]ifg@나는 한국에 있어 한국 오빠를 찾아서 같이 살고 싶다 나의 라인을...
# 29586  871890  [국제발신]ifg@요즘 잘 지내세요? *월 *일에 한국으로 여행 오고 싶은데, 같이...
# 29587  871891  [Web발신]ifg@(광고) 루이까스텔 대구신암쩜ifg@오픈**주년 기념 고객사은행...
#
# [29588 rows x 2 columns]

# %%
corpus = spam_df['CN'][0]   # CN 컬럼의 첫 번째 문장(인덱스 0)
corpus
# Out:
# '[Web발신]ifg@(광고)[한음대리점 율량점] 류태자 단골고객님ifg@ifg@마지막 최대할인입니다!!!!!!!ifg@SKT SKT SKT 기기변경 기기변경 ifg@ifg@▶▶▶▶▶Z플립* ***G◀◀◀◀◀ifg@☞☞☞☞공시지원금 기준☜☜☜☜ifg@ifg@기기값 : *,***,***원ifg@ifg@공시지원금 : -***,***원ifg@매장추가지원금 : -***,***원 ifg@ifg@★★★구매금액 : **,***원★★★ifg@ifg@***G 대용량 저장공간이라 오래오래 사용하실 수 있습니다!!!!ifg@극소량으로 조기종료가능성 있습니다ifg@ifg@▶ 단골이라서 더 드림 혜택 자세히 보기(SKT 공식 대리점 홈페이지로 연결) ifg@http://dangol.t-mms.kr/dt.do?m=*********&u=tworldfriends.co.kr/D*********ifg@ifg@(무료ARS)수신거부 및 단골해지 : ifg@***-***-****'

# %%
okt = Okt(jvmpath=r"C:\Program Files\Java\jdk-21\bin\server\jvm.dll") 
nouns = okt.nouns(corpus)
nouns
# Out:
# ['발신',
#  '광고',
#  '한음',
#  '대리점',
#  '율량점',
#  '류태자',
#  '단골',
#  '고객',
#  '마지막',
#  '최대',
#  '할인',
#  '기기',
#  '변경',
#  '기기',
#  '변경',
#  '플립',
#  '원금',
#  '기준',
#  '기기',
#  '값',
#  '원',
#  '원금',
#  '원',
#  '매장',
#  '추가',
#  '원금',
#  '원',
#  '구매',
#  '금액',
#  '원',
#  '용량',
#  '장공',
#  '오래오래',
#  '사용',
#  '수',
#  '소량',
#  '조기',
#  '종료',
#  '가능성',
#  '단골',
#  '더',
#  '드림',
#  '혜택',
#  '보기',
#  '공식',
#  '대리점',
#  '홈페이지',
#  '연결',
#  '무료',
#  '수신',
#  '거부',
#  '및',
#  '단골',
#  '해지']

# %%
word_count = Counter(nouns) # 명사 리스트에서 단어별 등장 횟수를 Counter({단어 : 빈도})
word_count
# Out:
# Counter({'원': 4,
#          '단골': 3,
#          '기기': 3,
#          '원금': 3,
#          '대리점': 2,
#          '변경': 2,
#          '발신': 1,
#          '광고': 1,
#          '한음': 1,
#          '율량점': 1,
#          '류태자': 1,
#          '고객': 1,
#          '마지막': 1,
#          '최대': 1,
#          '할인': 1,
#          '플립': 1,
#          '기준': 1,
#          '값': 1,
#          '매장': 1,
#          '추가': 1,
#          '구매': 1,
#          '금액': 1,
#          '용량': 1,
#          '장공': 1,
#          '오래오래': 1,
#          '사용': 1,
#          '수': 1,
#          '소량': 1,
#          '조기': 1,
#          '종료': 1,
#          '가능성': 1,
#          '더': 1,
#          '드림': 1,
#          '혜택': 1,
#          '보기': 1,
#          '공식': 1,
#          '홈페이지': 1,
#          '연결': 1,
#          '무료': 1,
#          '수신': 1,
#          '거부': 1,
#          '및': 1,
#          '해지': 1})

# %%
# 불용어 처리
ko_stopwords = ['및','더','수']
word_count = {word: count for word, count in word_count.items() if word not in ko_stopwords}
word_count
# Out:
# {'발신': 1,
#  '광고': 1,
#  '한음': 1,
#  '대리점': 2,
#  '율량점': 1,
#  '류태자': 1,
#  '단골': 3,
#  '고객': 1,
#  '마지막': 1,
#  '최대': 1,
#  '할인': 1,
#  '기기': 3,
#  '변경': 2,
#  '플립': 1,
#  '원금': 3,
#  '기준': 1,
#  '값': 1,
#  '원': 4,
#  '매장': 1,
#  '추가': 1,
#  '구매': 1,
#  '금액': 1,
#  '용량': 1,
#  '장공': 1,
#  '오래오래': 1,
#  '사용': 1,
#  '소량': 1,
#  '조기': 1,
#  '종료': 1,
#  '가능성': 1,
#  '드림': 1,
#  '혜택': 1,
#  '보기': 1,
#  '공식': 1,
#  '홈페이지': 1,
#  '연결': 1,
#  '무료': 1,
#  '수신': 1,
#  '거부': 1,
#  '해지': 1}

# %%
wordcloud = WordCloud(
    width=800,
    height=800,
    background_color='white',
    font_path= 'C:/Windows/Fonts/gulim.ttc'    
).generate_from_frequencies(word_count)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
corpus = spam_df['CN']
corpus
# Out:
# 0        [Web발신]ifg@(광고)[한음대리점 율량점] 류태자 단골고객님ifg@ifg@마지...
# 1        [Web발신]ifg@(광고)[전자랜드중동점]ifg@최은순 고객님!ifg@전자랜드 *...
# 2        제목 : (광고)현대미아점 통합ifg@▶*O,OOO원할인권◀도착ifg@현대미아 설화...
# 3        [Web발신]ifg@(광고) 신세계면세점 명동점ifg@ifg@본 문자 수신 고객님께...
# 4        [Web발신]ifg@(광고) 롯데마트 소중한 집사의 통장을 지켜라! 멍이도 냥이도 ...
#                                ...
# 29583    [국제발신]ifg@저한국에가는데 친구가 당신이공항에마중나올시간이있다고 했어요, 제L...
# 29584    [Web발신]ifg@(광고) 루이까스텔 인천구월*ifg@★루이까스텔 인천구월점★if...
# 29585    [국제발신]ifg@나는 한국에 있어 한국 오빠를 찾아서 같이 살고 싶다 나의 라인을...
# 29586    [국제발신]ifg@요즘 잘 지내세요? *월 *일에 한국으로 여행 오고 싶은데, 같이...
# 29587    [Web발신]ifg@(광고) 루이까스텔 대구신암쩜ifg@오픈**주년 기념 고객사은행...
# Name: CN, Length: 29588, dtype: object

# %%
okt = Okt(jvmpath=r"C:\Program Files\Java\jdk-21\bin\server\jvm.dll") 
nouns = []

for corpus_temp in corpus:
    nouns.extend(okt.nouns(corpus_temp))    # 문장별 명사 리스트를 추출해 nouns 리스테 이어붙임
    
nouns
# Out:
# ['발신',
#  '광고',
#  '한음',
#  '대리점',
#  '율량점',
#  '류태자',
#  '단골',
#  '고객',
#  '마지막',
#  '최대',
#  '할인',
#  '기기',
#  '변경',
#  '기기',
#  '변경',
#  '플립',
#  '원금',
#  '기준',
#  '기기',
#  '값',
#  '원',
#  '원금',
#  '원',
#  '매장',
#  '추가',
#  '원금',
#  '원',
#  '구매',
#  '금액',
#  '원',
#  '용량',
#  '장공',
#  '오래오래',
#  '사용',
#  '수',
#  '소량',
#  '조기',
#  '종료',
#  '가능성',
#  '단골',
#  '더',
#  '드림',
#  '혜택',
#  '보기',
#  '공식',
#  '대리점',
#  '홈페이지',
#  '연결',
#  '무료',
#  '수신',
#  '거부',
#  '및',
#  '단골',
#  '해지',
#  '발신',
#  '광고',
#  '전자랜드',
#  '동점',
#  '최은순',
#  '고객',
#  '전자랜드',
#  '월',
#  '전국동시',
#  '일',
#  '기간',
#  '토',
#  '월',
#  '가전제품',
#  '배달',
#  '전자랜드',
#  '배민',
#  '스토어',
#  '바로',
#  '배달',
#  '혼수',
#  '가전',
#  '견적',
#  '꼭',
#  '한번',
#  '곳',
#  '에어컨',
#  '추천',
#  '전문가',
#  '에어컨',
#  '만',
#  '냉장고',
#  '건조기',
#  '등',
#  '개',
#  '품목',
#  '전국동시',
#  '일',
#  '선풍기',
#  '인치',
#  '원',
#  '건조기',
#  '삼성',
#  '만',
#  '냉장고',
#  '만',
#  '인치',
#  '만',
#  '삼성',
#  '인치',
#  '만',
#  '아이폰',
#  '미니',
#  '갤럭시',
#  '학생',
#  '폰',
#  '추천',
#  '원',
#  '만원',
#  '모바일',
#  '행사',
#  '내용',
#  '보기',
#  '갤럭시',
#  '원',
#  '갤럭시',
#  '만원',
#  '갤럭시',
#  '울트라',
#  '만원',
#  '갤럭시',
#  '플립',
#  '만원',
#  '아이폰',
#  '미니',
#  '원',
#  '아이폰',
#  '원',
#  '아이폰',
#  '원',
#  '아이폰',
#  '프로',
#  '만원',
#  '개월',
#  '약정',
#  '통신',
#  '사별',
#  '가격',
#  '상이',
#  '새',
#  '것',
#  '전시',
#  '상품',
#  '오늘',
#  '득템',
#  '찬스',
#  '워',
#  '타워',
#  '분리',
#  '만원',
#  '워',
#  '타워',
#  '일체',
#  '만원',
#  '삼성',
#  '비',
#  '스포크',
#  '비',
#  '만원',
#  '무더위',
#  '극복',
#  '에어컨',
#  '특별',
#  '일',
#  '캐리어',
#  '에어로',
#  '단',
#  '만원',
#  '캐리어',
#  '오퍼스',
#  '만원',
#  '삼성',
#  '무풍',
#  '슬림',
#  '만원',
#  '삼성',
#  '비',
#  '스포크',
#  '갤러리',
#  '만원',
#  '청',
#  '가능',
#  '년',
#  '뷰',
#  '만원',
#  '실속',
#  '칸',
#  '만원',
#  '노트북',
#  '모바일',
#  '사무',
#  '게임',
#  '전문가',
#  '순정',
#  '부품',
#  '사용',
#  '조립',
#  '노트북',
#  '그램',
#  '성북',
#  '프로',
#  '특별',
#  '노트북',
#  '성북',
#  '만',
#  '시스템',
#  '에어컨',
#  '냉',
#  '방기',
#  '사무실',
#  '상가',
#  '냉',
#  '방기',
#  '신축',
#  '주택',
#  '시스템',
#  '에어컨',
#  '전문',
#  '시공',
#  '혼수',
#  '가전',
#  '전문',
#  '상담',
#  '운영',
#  '검색',
#  '전자랜드',
#  '중동',
#  '점',
#  '검색',
#  '사전',
#  '상담',
#  '예약',
#  '사전예약',
#  '최저',
#  '보장',
#  '시행',
#  '식기세척기',
#  '무선',
#  '청소기',
#  '음식물',
#  '처리기',
#  '안마',
#  '의자',
#  '생활',
#  '가전',
#  '세라',
#  '젬',
#  '공무원',
#  '제휴',
#  '카드',
#  '혜택',
#  '포함',
#  '월',
#  '최대',
#  '혜택',
#  '주간',
#  '꼭',
#  '한번',
#  '성심껏',
#  '최선',
#  '가전제품',
#  '고장',
#  '걱정',
#  '사용',
#  '방법',
#  '전자랜드',
#  '롯데',
#  '손해',
#  '보험',
#  '가전제품',
#  '년',
#  '무상',
#  '보증',
#  '서비스',
#  '가전제품',
#  '생활',
#  '파워',
#  '케어',
#  '출시',
#  '가전',
#  '구매',
#  '시',
#  '확인',
#  '준법',
#  '심의',
#  '필',
#  '제',
#  '호',
#  '무료',
#  '수신',
#  '거부',
#  '제목',
#  '광고',
#  '현대',
#  '미아',
#  '점',
#  '통합',
#  '할인',
#  '도착',
#  '현대',
#  '미아',
#  '설화수',
#  '헤라',
#  '기간',
#  '월',
#  '일',
#  '금',
#  '일',
#  '일',
#  '문의',
#  '이상구',
#  '고급',
#  '특대',
#  '장바구니',
#  '증정',
#  '매장',
#  '할인',
#  '할인',
#  '할인',
#  '백',
#  '카드',
#  '결제',
#  '시',
#  '기초',
#  '종',
#  '증정',
#  '최종',
#  '금액',
#  '원',
#  '이상구',
#  '고급',
#  '특대',
#  '장바구니',
#  '증정',
#  '매장',
#  '할인',
#  '할인',
#  '할인',
#  '백',
#  '카드',
#  '최종',
#  '금액',
#  '원',
#  '정품',
#  '용량',
#  '스킨',
#  '자음',
#  '생수',
#  '스킨',
#  '자음',
#  '생수',
#  '스킨',
#  '자음',
#  '생수',
#  '정품',
#  '용량',
#  '로션',
#  '자음',
#  '생',
#  '유액',
#  '로션',
#  '자음',
#  '생',
#  '유액',
#  '로션',
#  '자음',
#  '생',
#  '유액',
#  '정품',
#  '용량',
#  '에센스',
#  '자음',
#  '생',
#  '럼',
#  '에센스',
#  '자음',
#  '생',
#  '럼',
#  '에센스',
#  '자음',
#  '생',
#  '럼',
#  '에센스',
#  '자음',
#  '생',
#  '럼',
#  '에센스',
#  '자음',
#  '생',
#  '럼',
#  '정품',
#  '용량',
#  '크림',
#  '자음',
#  '생크림',
#  '크림',
#  '자음',
#  '생크림',
#  '크림',
#  '자음',
#  '생크림',
#  '크림',
#  '자음',
#  '생크림',
#  '크림',
#  '자음',
#  '생크림',
#  '크림',
#  '자음',
#  '생크림',
#  '이상구',
#  '고급',
#  '특대',
#  '장바구니',
#  '증정',
#  '매장',
#  '할인',
#  '할인',
#  '할인',
#  '백',
#  '카드',
#  '최종',
#  '금액',
#  '원',
#  '정품',
#  '용량',
#  '프리미엄',
#  '진설',
#  '수',
#  '프리미엄',
#  '진설',
#  '수',
#  '프리미엄',
#  '진설',
#  '수',
#  '정품',
#  '용량',
#  '프리미엄',
#  '진설',
#  '유액',
#  '프리미엄',
#  '진설',
#  '유액',
#  '프리미엄',
#  '진설',
#  '유액',
#  '정품',
#  '용량',
#  '프리미엄',
#  '진설',
#  '럼',
#  '프리미엄',
#  '진설',
#  '럼',
#  '프리미엄',
#  '진설',
#  '럼',
#  '프리미엄',
#  '진설',
#  '럼',
#  '프리미엄',
#  '진설',
#  '럼',
#  '정품',
#  '용량',
#  '프리미엄',
#  '진설',
#  '크림',
#  '프리미엄',
#  '진설',
#  '크림',
#  '프리미엄',
#  '진설',
#  '크림',
#  '프리미엄',
#  '진설',
#  '크림',
#  '프리미엄',
#  '진설',
#  '크림',
#  '프리미엄',
#  '진설',
#  '크림',
#  '중복',
#  '불가',
#  '인',
#  '회',
#  '참여',
#  '가능',
#  '중복',
#  '불가',
#  '제시',
#  '고객',
#  '함',
#  '품절',
#  '가능',
#  '문의',
#  '현대',
#  '미아',
#  '점',
#  '통합',
#  '무료',
#  '수신',
#  '거부',
#  '발신',
#  '광고',
#  '신세계',
#  '면세점',
#  '명동',
#  '점',
#  '문자',
#  '수신',
#  '고객',
#  '만',
#  '신세계',
#  '면세점',
#  '명동',
#  '점',
#  '시크릿',
#  '혜택',
#  '시크릿',
#  '행사',
#  '기간',
#  '금',
#  '일',
#  '시크릿',
#  '혜택',
#  '김현중',
#  '님',
#  '회원',
#  '계정',
#  '신세계',
#  '면세점',
#  '명동',
#  '점',
#  '결제',
#  '시',
#  '즉시',
#  '할인',
#  '쇼핑',
#  '원금',
#  '종이',
#  '지급',
#  '이상',
#  '구매',
#  '시',
#  '만원',
#  '즉시',
#  '사용',
#  '가능',
#  '유의사항',
#  '명동',
#  '점',
#  '오프라인',
#  '매장',
#  '사용',
#  '가능',
#  '유효',
#  '기간',
#  '발급',
#  '일로',
#  '일',
#  '일부',
#  '브랜드',
#  '사용',
#  '제외',
#  '쇼핑',
#  '지원',
#  '금은',
#  '기타',
#  '쇼핑',
#  '원금',
#  '중복',
#  '사용',
#  '불가',
#  '본인',
#  '외',
#  '사용',
#  '및',
#  '타인',
#  '양도',
#  '불가',
#  '지급',
#  '역',
#  '신세계',
#  '면세점',
#  '앱',
#  '마이',
#  '페이지',
#  '확인',
#  '마이',
#  '페이지',
#  '바로',
#  '가기',
#  '시크릿',
#  '혜택',
#  '증정',
#  '장소',
#  '명동',
#  '점',
#  '고객',
#  '센터',
#  '여권',
#  '당일',
#  '구매',
#  '영수증',
#  '및',
#  '해당',
#  '문자',
#  '제시',
#  '필수',
#  '면세',
#  '포인트',
#  '최대',
#  '만원',
#  '추가',
#  '증정',
#  '이상',
#  '구매',
#  '시',
#  '만원',
#  '증정',
#  '트래블',
#  '폴딩백',
#  '추가',
#  '증정',
#  '이상',
#  '구매',
#  '시',
#  '보기',
#  '시크릿',
#  '이벤트',
#  '신세계',
#  '면세점',
#  '내부',
#  '사정',
#  '전고지',
#  '변경',
#  '조기',
#  '종료',
#  '수',
#  '명동',
#  '점',
#  '영업',
#  '시간',
#  '안내',
#  '월',
#  '목',
#  '금',
#  '일',
#  '공휴일',
#  '통합',
#  '콜센터',
#  '무료',
#  '수신',
#  '거부',
#  '발신',
#  '광고',
#  '롯데',
#  '마트',
#  '집사',
#  '통장',
#  '멍',
#  '냥',
#  '집사',
#  '득',
#  '템',
#  '위',
#  '박은혜',
#  '배',
#  '적립',
#  '쿠폰',
#  '쿠폰',
#  '확인',
#  '콜리',
#  '개이득',
#  '냥',
#  '이득',
#  '득템',
#  '위',
#  '여종',
#  '최대',
#  '할인',
#  '반려동물',
#  '용품',
#  '식품',
#  '만원',
#  '이상',
#  '구매',
#  '시',
#  '천원',
#  '할인',
#  '쿠폰',
#  '증정',
#  '월',
#  '달',
#  '간',
#  '사용',
#  '가능',
#  '영수증',
#  '자동',
#  '발급',
#  '일부',
#  '품목',
#  '제외',
#  '대표',
#  '상품',
#  '콜리',
#  '사용',
#  '회용',
#  '패드',
#  '종',
#  '카드',
#  '할인',
#  '원',
#  '원',
#  '원',
#  '정상',
#  '원',
#  '원',
#  '원',
#  '매',
#  '매',
#  '매',
#  '롯데',
#  '신한',
#  '농협카드',
#  '결제',
#  '시',
#  '함',
#  '피랩',
#  '마음',
#  '종',
#  '카드',
#  '할인',
#  '원',
#  '정상',
#  '원',
#  '오리',
#  '치킨',
#  '슬',
#  '라이스',
#  '오리',
#  '치킨',
#  '우유',
#  '껌',
#  '이나',
#  '바',
#  '고양이',
#  '용량',
#  '츄르',
#  '회원',
#  '할인',
#  '카드',
#  '할인',
#  '할인',
#  '일부',
#  '품목',
#  '함',
#  '롯데',
#  '신한',
#  '농협카드',
#  '결제',
#  '시',
#  '함',
#  '기간',
#  '목',
#  '수',
#  '문자',
#  '고객',
#  '롯데',
#  '마트',
#  '바코드',
#  '스캔',
#  '시',
#  '적용',
#  '점',
#  '재고',
#  '상이',
#  '조기',
#  '품절',
#  '수',
#  '무료',
#  '수신',
#  '거부',
#  '광고',
#  '여름',
#  '준비',
#  '깜짝',
#  '증정',
#  '행사',
#  '돌체',
#  '스토',
#  '스타벅스',
#  '캡슐',
#  '구매',
#  '스타벅스',
#  '한정',
#  '굿',
#  '를',
#  '가세',
#  '캡슐',
#  '박스',
#  '구매',
#  '시',
#  '한정판',
#  '스타벅스',
#  '텀블러',
#  '캡슐',
#  '박스',
#  '구매',
#  '시',
#  '스타벅스',
#  '아이스',
#  '글라스',
#  '스푼',
#  '세트',
#  '행사',
#  '기간',
#  '목',
#  '단',
#  '일간',
#  '진행',
#  '한정',
#  '혜택',
#  '돌체',
#  '스토',
#  '여름',
#  '미리',
#  '준비',
#  '프로모션',
#  '참여',
#  '유의',
#  '사항',
#  '스타벅스',
#  '캡슐',
#  '돌체',
#  '스토',
#  '캡슐',
#  '구매',
#  '시',
#  '증정',
#  '품',
#  '증정',
#  '정기',
#  '배송',
#  '증정',
#  '품',
#  '행사',
#  '제외',
#  '재고',
#  '상황',
#  '행사',
#  '조기',
#  '종료',
#  '수',
#  '유의',
#  '사항',
#  '프로모션',
#  '링크',
#  '참고',
#  '문의',
#  '사항',
#  '공식',
#  '콜센터',
#  '평일',
#  '월',
#  '금',
#  '시',
#  '시',
#  '로',
#  '연락',
#  '답변',
#  '무료',
#  '수신',
#  '거부',
#  '발신',
#  '광고',
#  '우리',
#  '한우',
#  '우리',
#  '한우',
#  '세리',
#  '스마트',
#  '전단',
#  '안심',
#  '주문',
#  '세리',
#  '스마트',
#  '전단',
#  '안심',
#  '주문',
#  '우리',
#  '한우',
#  '전단',
#  '행사',
#  '마지막',
#  '날',
#  '매일',
#  '야채',
#  '청과',
#  '지역',
#  '최저',
#  '가격',
#  '일별',
#  '행사',
#  '품목',
#  '화요일',
#  '일',
#  '한우',
#  '암소',
#  '채끝',
#  '등심',
#  '원',
#  '초특',
#  '돈',
#  '생',
#  '앞다리',
#  '살',
#  '원',
#  '초특',
#  '한우',
#  '암소',
#  '불고기',
#  '등급',
#  '이상',
#  '원',
#  '초',
#  '대박',
#  '특',
#  '한정',
#  '진시',
#  '행사',
#  '종료',
#  '상',
#  '판매',
#  '행사',
#  '품목',
#  '돈',
#  '생',
#  '등',
#  '갈비',
#  '원',
#  '돈',
#  '생',
#  '갈비',
#  '원',
#  '돈',
#  '생',
#  '등뼈',
#  '원',
#  '한우',
#  '암소',
#  '꽃',
#  '등심',
#  '원',
#  '한우',
#  '암소',
#  '부채살',
#  '원',
#  '한우',
#  '암소',
#  '살',
#  '원',
#  '한우',
#  '암소',
#  '모',
#  '구이',
#  '원',
#  '한우',
#  '암소',
#  '육회',
#  '팩',
#  '원',
#  '소스',
#  '증정',
#  '한우',
#  '암소',
#  '국',
#  '거리',
#  '원',
#  '한우',
#  '암소',
#  '양지',
#  '원',
#  '한우',
#  '암소',
#  '족',
#  '개',
#  '원',
#  '잡뼈',
#  '써비스',
#  '명품',
#  '갈비',
#  '원',
#  '오리',
#  ...]

# %%
word_count = Counter(nouns)

ko_stopwords = ['은','는','이','가','및','더','수']

word_count = {word : count for word, count in word_count.items() if word not in ko_stopwords}
word_count
# Out:
# {'발신': 26353,
#  '광고': 25446,
#  '한음': 5,
#  '대리점': 855,
#  '율량점': 34,
#  '류태자': 1,
#  '단골': 2287,
#  '고객': 33549,
#  '마지막': 2442,
#  '최대': 15122,
#  '할인': 30235,
#  '기기': 3872,
#  '변경': 2466,
#  '플립': 1202,
#  '원금': 4092,
#  '기준': 5933,
#  '값': 2015,
#  '원': 73117,
#  '매장': 9479,
#  '추가': 15801,
#  '구매': 27228,
#  '금액': 5972,
#  '용량': 1015,
#  '장공': 4,
#  '오래오래': 8,
#  '사용': 11172,
#  '소량': 106,
#  '조기': 3812,
#  '종료': 5280,
#  '가능성': 16,
#  '드림': 760,
#  '혜택': 37313,
#  '보기': 3636,
#  '공식': 1502,
#  '홈페이지': 1511,
#  '연결': 854,
#  '무료': 28284,
#  '수신': 18229,
#  '거부': 19429,
#  '해지': 1604,
#  '전자랜드': 1156,
#  '동점': 232,
#  '최은순': 2,
#  '월': 35426,
#  '전국동시': 117,
#  '일': 32982,
#  '기간': 13622,
#  '토': 2928,
#  '가전제품': 2312,
#  '배달': 335,
#  '배민': 45,
#  '스토어': 1787,
#  '바로': 5521,
#  '혼수': 585,
#  '가전': 7012,
#  '견적': 219,
#  '꼭': 3270,
#  '한번': 779,
#  '곳': 401,
#  '에어컨': 3823,
#  '추천': 1764,
#  '전문가': 1121,
#  '만': 9399,
#  '냉장고': 2111,
#  '건조기': 1402,
#  '등': 9357,
#  '개': 10497,
#  '품목': 5019,
#  '선풍기': 634,
#  '인치': 1411,
#  '삼성': 5379,
#  '아이폰': 2388,
#  '미니': 1257,
#  '갤럭시': 6138,
#  '학생': 182,
#  '폰': 3377,
#  '만원': 40255,
#  '모바일': 3115,
#  '행사': 18626,
#  '내용': 4837,
#  '울트라': 354,
#  '프로': 2076,
#  '개월': 8413,
#  '약정': 807,
#  '통신': 270,
#  '사별': 182,
#  '가격': 2574,
#  '상이': 1568,
#  '새': 1278,
#  '것': 1174,
#  '전시': 1480,
#  '상품': 11217,
#  '오늘': 2304,
#  '득템': 520,
#  '찬스': 1077,
#  '워': 1634,
#  '타워': 1500,
#  '분리': 82,
#  '일체': 102,
#  '비': 2678,
#  '스포크': 289,
#  '무더위': 403,
#  '극복': 86,
#  '특별': 5361,
#  '캐리어': 580,
#  '에어로': 91,
#  '단': 3571,
#  '오퍼스': 15,
#  '무풍': 784,
#  '슬림': 186,
#  '갤러리': 700,
#  '청': 343,
#  '가능': 9739,
#  '년': 12357,
#  '뷰': 500,
#  '실속': 584,
#  '칸': 54,
#  '노트북': 334,
#  '사무': 65,
#  '게임': 205,
#  '순정': 28,
#  '부품': 139,
#  '조립': 68,
#  '그램': 310,
#  '성북': 43,
#  '시스템': 823,
#  '냉': 275,
#  '방기': 171,
#  '사무실': 109,
#  '상가': 553,
#  '신축': 418,
#  '주택': 1109,
#  '전문': 727,
#  '시공': 228,
#  '상담': 9904,
#  '운영': 1774,
#  '검색': 296,
#  '중동': 101,
#  '점': 11346,
#  '사전': 1330,
#  '예약': 8173,
#  '사전예약': 2145,
#  '최저': 1657,
#  '보장': 3413,
#  '시행': 209,
#  '식기세척기': 940,
#  '무선': 438,
#  '청소기': 432,
#  '음식물': 178,
#  '처리기': 171,
#  '안마': 288,
#  '의자': 320,
#  '생활': 1833,
#  '세라': 117,
#  '젬': 96,
#  '공무원': 342,
#  '제휴': 2559,
#  '카드': 6938,
#  '포함': 1660,
#  '주간': 338,
#  '성심껏': 69,
#  '최선': 713,
#  '고장': 365,
#  '걱정': 865,
#  '방법': 3621,
#  '롯데': 4239,
#  '손해': 3650,
#  '보험': 16725,
#  '무상': 2724,
#  '보증': 1358,
#  '서비스': 3324,
#  '파워': 496,
#  '케어': 3420,
#  '출시': 3276,
#  '시': 42435,
#  '확인': 9370,
#  '준법': 1636,
#  '심의': 1170,
#  '필': 1944,
#  '제': 4225,
#  '호': 2556,
#  '제목': 91,
#  '현대': 2402,
#  '미아': 198,
#  '통합': 399,
#  '도착': 2269,
#  '설화수': 176,
#  '헤라': 89,
#  '금': 10066,
#  '문의': 11578,
#  '이상구': 222,
#  '고급': 753,
#  '특대': 176,
#  '장바구니': 260,
#  '증정': 35200,
#  '백': 200,
#  '결제': 3651,
#  '기초': 318,
#  '종': 4444,
#  '최종': 302,
#  '정품': 1004,
#  '스킨': 358,
#  '자음': 349,
#  '생수': 92,
#  '로션': 155,
#  '생': 1773,
#  '유액': 86,
#  '에센스': 428,
#  '럼': 335,
#  '크림': 818,
#  '생크림': 85,
#  '프리미엄': 3405,
#  '진설': 116,
#  '중복': 2244,
#  '불가': 2734,
#  '인': 4481,
#  '회': 6019,
#  '참여': 6632,
#  '제시': 552,
#  '함': 1978,
#  '품절': 1726,
#  '신세계': 7104,
#  '면세점': 690,
#  '명동': 322,
#  '문자': 8404,
#  '시크릿': 1056,
#  '김현중': 3,
#  '님': 211,
#  '회원': 3204,
#  '계정': 781,
#  '즉시': 1871,
#  '쇼핑': 2897,
#  '종이': 115,
#  '지급': 8185,
#  '이상': 15151,
#  '유의사항': 991,
#  '오프라인': 257,
#  '유효': 817,
#  '발급': 1219,
#  '일로': 209,
#  '일부': 3326,
#  '브랜드': 4080,
#  '제외': 4744,
#  '지원': 1907,
#  '금은': 175,
#  '기타': 489,
#  '본인': 1073,
#  '외': 1322,
#  '타인': 267,
#  '양도': 158,
#  '역': 1912,
#  '앱': 2153,
#  '마이': 1297,
#  '페이지': 1866,
#  '가기': 1936,
#  '장소': 1330,
#  '센터': 5995,
#  '여권': 72,
#  '당일': 2334,
#  '영수증': 731,
#  '해당': 2559,
#  '필수': 1973,
#  '면세': 59,
#  '포인트': 5515,
#  '트래블': 107,
#  '폴딩백': 49,
#  '이벤트': 15859,
#  '내부': 98,
#  '사정': 1109,
#  '전고지': 52,
#  '영업': 861,
#  '시간': 4112,
#  '안내': 10084,
#  '목': 4282,
#  '공휴일': 231,
#  '콜센터': 90,
#  '마트': 1497,
#  '집사': 48,
#  '통장': 624,
#  '멍': 25,
#  '냥': 50,
#  '득': 43,
#  '템': 750,
#  '위': 5851,
#  '박은혜': 5,
#  '배': 719,
#  '적립': 1943,
#  '쿠폰': 15460,
#  '콜리': 38,
#  '개이득': 18,
#  '이득': 124,
#  '여종': 34,
#  '반려동물': 64,
#  '용품': 255,
#  '식품': 1641,
#  '천원': 7226,
#  '달': 3161,
#  '간': 469,
#  '자동': 1130,
#  '대표': 1731,
#  '회용': 20,
#  '패드': 311,
#  '정상': 2073,
#  '매': 1409,
#  '신한': 755,
#  '농협카드': 224,
#  '피랩': 17,
#  '마음': 470,
#  '오리': 374,
#  '치킨': 413,
#  '슬': 478,
#  '라이스': 396,
#  '우유': 445,
#  '껌': 21,
#  '이나': 40,
#  '바': 770,
#  '고양이': 33,
#  '츄르': 21,
#  '바코드': 156,
#  '스캔': 77,
#  '적용': 4575,
#  '재고': 1008,
#  '여름': 5221,
#  '준비': 2839,
#  '깜짝': 152,
#  '돌체': 18,
#  '스토': 20,
#  '스타벅스': 3403,
#  '캡슐': 296,
#  '한정': 10613,
#  '굿': 324,
#  '를': 1185,
#  '가세': 345,
#  '박스': 2973,
#  '한정판': 121,
#  '텀블러': 121,
#  '아이스': 205,
#  '글라스': 81,
#  '스푼': 9,
#  '세트': 4297,
#  '일간': 2087,
#  '진행': 4085,
#  '미리': 717,
#  '프로모션': 1249,
#  '유의': 385,
#  '사항': 3646,
#  '품': 6308,
#  '정기': 628,
#  '배송': 2037,
#  '상황': 223,
#  '링크': 2121,
#  '참고': 495,
#  '평일': 837,
#  '로': 2604,
#  '연락': 2212,
#  '답변': 129,
#  '우리': 2360,
#  '한우': 5666,
#  '세리': 37,
#  '스마트': 412,
#  '전단': 593,
#  '안심': 1341,
#  '주문': 1741,
#  '날': 788,
#  '매일': 1644,
#  '야채': 411,
#  '청과': 172,
#  '지역': 727,
#  '일별': 66,
#  '화요일': 84,
#  '암소': 336,
#  '채끝': 294,
#  '등심': 1151,
#  '초특': 980,
#  '돈': 3060,
#  '앞다리': 454,
#  '살': 2018,
#  '불고기': 1641,
#  '등급': 2109,
#  '초': 1956,
#  '대박': 263,
#  '특': 6583,
#  '진시': 1309,
#  '상': 290,
#  '판매': 2587,
#  '갈비': 1245,
#  '등뼈': 204,
#  '꽃': 1045,
#  '부채살': 222,
#  '모': 225,
#  '구이': 422,
#  '육회': 706,
#  '팩': 6368,
#  '소스': 675,
#  '국': 684,
#  '거리': 1515,
#  '양지': 292,
#  '족': 265,
#  '잡뼈': 135,
#  '써비스': 37,
#  '명품': 703,
#  '훈제': 164,
#  '대란': 298,
#  '판': 491,
#  '양념': 1261,
#  '수제': 361,
#  '돈가스': 41,
#  '장': 1515,
#  '돼지갈비': 149,
#  '떡갈비': 143,
#  '사골곰국': 22,
#  '파우치': 425,
#  '윤병섭님': 2,
#  '환급': 1915,
#  '모두': 1528,
#  '축하': 1519,
#  '국외': 2094,
#  '나': 2615,
#  '한국': 4463,
#  '너': 499,
#  '안': 1036,
#  '탑': 87,
#  '거래소': 76,
#  '해운대': 310,
#  '비치': 179,
#  '매물': 99,
#  '포웰': 8,
#  '부산': 1614,
#  '분양': 4221,
#  '드': 315,
#  '일반': 1210,
#  '가야': 44,
#  '우대': 113,
#  '주중': 287,
#  '통': 1827,
#  '용': 2834,
#  '여': 165,
#  '동래': 181,
#  '전세': 253,
#  '객실': 69,
#  '오션': 359,
#  '풀이': 4,
#  '세계': 209,
#  '얀': 12,
#  '트리': 366,
#  '직통': 377,
#  '멤버십': 2714,
#  '공통': 157,
#  '편의점': 522,
#  '베이커리': 202,
#  '파리': 350,
#  '바게뜨': 218,
#  '뚜레주르': 150,
#  '파리크라상': 150,
#  '주요': 296,
#  '매달': 572,
#  '택': 1405,
#  '네이버': 2872,
#  '플러스': 1440,
#  '구독': 6430,
#  '유독': 94,
#  '유튜브': 211,
#  '밀리': 159,
#  '서재': 103,
#  '메가박스': 196,
#  '예매': 1333,
#  '윌': 151,
#  '오디오북': 94,
#  '리디': 92,
#  '셀렉': 113,
#  '트': 364,
#  '요기': 118,
#  '공차': 98,
#  '할리스': 92,
#  '베': 216,
#  '월드': 229,
#  '에버랜드': 175,
#  '아쿠아리움': 92,
#  '서울': 1544,
#  '스카이': 279,
#  '이용권': 518,
#  '지금': 4056,
#  '영화': 277,
#  '만족도': 2671,
#  '조사': 2940,
#  '개인': 1215,
#  '급전': 33,
#  '대출': 637,
#  '누구': 496,
#  '조건': 3532,
#  '승인': 190,
#  '카카오': 2916,
#  '톡': 2015,
#  '비대': 334,
#  '워킹': 14,
#  '신제품': 1379,
#  '이밴트': 3,
#  '최초': 993,
#  '유일': 140,
#  '진짜': 233,
#  '진동': 33,
#  '신발': 97,
#  '골든타임': 49,
#  '혈류': 7,
#  '기념': 2646,
#  '자기': 187,
#  '방문': 7414,
#  '차도': 3,
#  '한잔': 48,
#  '기회': 1798,
#  '잡고': 57,
#  '건강': 5134,
#  '영등포': 57,
#  '익산': 118,
#  '농협': 1052,
#  '로컬': 234,
#  '푸드': 381,
#  '직매': 79,
#  '등점': 33,
#  '밴드': 306,
#  '금토일': 52,
#  '축산': 480,
#  '코너': 738,
#  '돈암': 154,
#  '돼지': 961,
#  '삼겹살': 1053,
#  '목살': 324,
#  '족발': 38,
#  '주물': 102,
#  '럭': 88,
#  '하림': 267,
#  '닭다리': 38,
#  '정육': 476,
#  '수산': 474,
#  '왕궁': 15,
#  '우렁이': 18,
#  '갑오징어': 49,
#  '마리': 1498,
#  '오징어': 409,
#  '농산': 213,
#  '참외': 859,
#  '봉지': 388,
#  '천도': 390,
#  '복숭아': 834,
#  '팽이버섯': 144,
#  '묶음': 179,
#  '오이': 679,
#  '개입': 801,
#  '공산': 236,
#  '특급': 226,
#  '레비': 9,
#  '라임': 16,
#  '레몬': 269,
#  '플레인': 26,
#  '수량': 2756,
#  '오뚜기': 886,
#  '분': 4397,
#  '카레': 64,
#  '맛': 620,
#  '약간': 14,
#  '햇반': 247,
#  '팔도': 220,
#  '비빔면': 281,
#  '후': 6887,
#  '레쉬': 70,
#  '리지': 158,
#  '널': 214,
#  '백설': 472,
#  '소시지': 66,
#  '느낌': 59,
#  '오버': 39,
#  '중': 3547,
#  '보쌈': 92,
#  '사태': 366,
#  '찜': 188,
#  '탕용': 30,
#  '차돌박이': 209,
#  '샤브샤브': 140,
#  '스테이크': 128,
#  '타임세일': 164,
#  '오후': 2212,
#  '수박': 1528,
#  '팩귤': 19,
#  '송이버섯': 183,
#  '깻잎': 279,
#  '빵가루': 21,
#  '새우': 273,
#  '건조': 372,
#  '박대': 12,
#  '선동': 40,
#  '제주': 852,
#  '갈치': 205,
#  '동태': 67,
#  '포': 2422,
#  '능이': 8,
#  '닭백숙': 8,
#  '공동': 276,
#  '바로가기': 1186,
#  '오전': 1395,
#  '처': 796,
#  '무조건': 562,
#  '사은': 7386,
#  '이점': 59,
#  '양해': 321,
#  '국제': 4427,
#  '저': 1366,
#  '대한민국': 561,
#  '예정': 2985,
#  '공항': 950,
#  '마중': 511,
#  '울릉도': 48,
#  '마가': 131,
#  '보감': 138,
#  '지대': 105,
#  '천연': 98,
#  '비아그라': 17,
#  '격': 153,
#  '전': 5022,
#  '한시': 135,
#  '유예': 78,
#  '곧': 259,
#  '마감': 1785,
#  '이제': 1984,
#  '절대': 347,
#  '다시': 777,
#  '예전': 28,
#  '그대로': 518,
#  '더블': 1662,
#  '구성': 590,
#  '기존': 1860,
#  '침향': 2135,
#  '환': 1278,
#  '뭔가': 20,
#  '가지': 1348,
#  '이슬': 33,
#  '크게': 71,
#  '뜻': 19,
#  '기력': 59,
#  '활': 373,
#  '정력': 25,
#  '지구력': 106,
#  '체력': 91,
#  '기능': 2019,
#  '향상': 59,
#  '혈액': 88,
#  '순환': 183,
#  '관문': 100,
#  '비수리': 89,
#  '오자': 22,
#  '성분': 343,
#  '남자': 178,
#  '자존심': 22,
#  '제품': 5221,
#  '말': 310,
#  '기운': 81,
#  '얼마나': 67,
#  '지인': 296,
#  '가족': 1535,
#  '친구': 1101,
#  '등등': 165,
#  '개시': 104,
#  '선물': 2526,
#  '전화': 3734,
#  '주시': 1059,
#  '울릉': 33,
#  '산림': 33,
#  '총괄': 97,
#  '실장': 1421,
#  '혜란': 5,
#  '구미': 118,
#  '칠곡': 44,
#  '축협': 91,
#  '하나로마트': 618,
#  '화': 1929,
#  '기소진': 298,
#  '돈육': 43,
#  '브리': 125,
#  '냉장': 642,
#  '갈매기살': 27,
#  '냉동': 498,
#  '과일': 369,
#  '도선': 134,
#  '별': 3280,
#  '하우스': 674,
#  '토마토': 580,
#  '바나나': 560,
#  '손': 407,
#  '성주': 214,
#  '채소': 327,
#  '풋': 71,
#  '호박': 153,
#  '청양고추': 133,
#  '단호박': 171,
#  '애호박': 512,
#  '가시': 140,
#  '입': 3998,
#  '상추': 157,
#  '생물': 297,
#  '고등어': 301,
#  '손질': 201,
#  '전복': 283,
#  '꼬막': 16,
#  '물회': 121,
#  '육수': 369,
#  '모듬회': 26,
#  '숙회': 13,
#  '해표': 145,
#  '순창': 85,
#  '궁': 60,
#  '골드': 1050,
#  '고추장': 502,
#  '메': 654,
#  '핫도그': 148,
#  '치즈': 474,
#  '크리스': 35,
#  '피': 639,
#  '코디': 68,
#  '내추럴': 26,
#  '미용': 73,
#  '티슈': 266,
#  '수퍼': 151,
#  '타이': 47,
#  '샤프란': 71,
#  '릴렉': 11,
#  '싱아': 7,
#  '로마': 40,
#  '코튼': 65,
#  '앤': 811,
#  '핑크': 138,
#  '센세이션': 5,
#  '카톡': 625,
#  '윤': 84,
#  '예찬': 3,
#  '여러분': 527,
#  '무': 3960,
#  '방': 1079,
#  '문': 175,
#  '승': 319,
#  '주': 2167,
#  '부': 395,
#  '직': 107,
#  '신': 226,
#  '속': 800,
#  '도마': 79,
#  '변동': 389,
#  '구역': 470,
#  '대장': 180,
#  '아파트': 2818,
#  '힐스테이트': 749,
#  '가장': 948,
#  '퍼스트': 147,
#  '선착순': 5821,
#  '지정': 1245,
#  '계약금': 1877,
#  '대전': 940,
#  '서구': 186,
#  '양제': 90,
#  '실시': 225,
#  '최화영': 1,
#  '과장': 305,
#  '정관': 2587,
#  '힘': 1549,
#  '더위': 1174,
#  '체험': 2232,
#  '시점': 1016,
#  '홍삼': 2080,
#  '톤류': 145,
#  '류': 243,
#  '모든': 2504,
#  '대상': 6038,
#  '리': 1510,
#  '유저': 632,
#  '블': 705,
#  '소진': 2123,
#  '버스': 953,
#  '정류': 472,
#  '액': 2678,
#  '아이': 1995,
#  '패스': 683,
#  '병': 1054,
#  '현재': 886,
#  '전남': 43,
#  '조례': 33,
#  '카다': 434,
#  '로그': 592,
#  '방역': 420,
#  '위생': 449,
#  '관리': 2300,
#  '딜': 542,
#  '라이브': 6745,
#  '폭염': 289,
#  '온라인': 1210,
#  '도전': 270,
#  '스탠드': 431,
#  '절호': 288,
#  '여기': 222,
#  '우수': 1346,
#  '하나': 1985,
#  '기사': 155,
#  '이내': 556,
#  '설치': 1006,
#  '전자': 3294,
#  '평': 4676,
#  '할부': 1487,
#  '접수': 765,
#  '한해': 511,
#  '완료': 1377,
#  '별도': 1179,
#  '택배': 289,
#  '커피': 1067,
#  '전월': 125,
#  '이용': 5125,
#  '실적': 364,
#  '전일': 68,
#  '마케팅': 1439,
#  '신동': 94,
#  '발송': 2797,
#  '신한카드': 677,
#  '고학': 6,
#  '상품권': 13739,
#  '숫자': 103,
#  '답장': 836,
#  '신청': 4921,
#  '상세': 595,
#  '시불': 231,
#  '합산': 1682,
#  '다음': 629,
#  '총': 3835,
#  '말일': 76,
#  '제공': 6410,
#  '디스커버': 24,
#  '하루': 1877,
#  '분만': 109,
#  '투자': 1292,
#  '트렌드': 80,
#  '강사': 102,
#  '최신': 402,
#  '정보': 1903,
#  '주의': 404,
#  '당사': 1145,
#  '등록': 1427,
#  '휴대폰': 2295,
#  '번호': 2530,
#  '회신': 301,
#  '응모': 1168,
#  '익월': 60,
#  '중순': 34,
#  '이후': 666,
#  '체크': 230,
#  '법인': 628,
#  '기프트': 554,
#  '교통': 515,
#  '요금': 1825,
#  '비용': 1845,
#  '부담': 816,
#  '계약': 8506,
#  '체결': 3102,
#  '회비': 649,
#  '설명': 1908,
#  '약관': 1263,
#  '참조': 442,
#  '금융': 1532,
#  '소비자보호법': 23,
#  '조': 191,
#  '항': 537,
#  '대해': 442,
#  '권리': 138,
#  '신용카드': 689,
#  '부적정': 17,
#  '경우': 1386,
#  '연체': 391,
#  '단기': 219,
#  '사유': 563,
#  '발생': 1162,
#  '신용': 639,
#  '평점': 505,
#  '제한': 2636,
#  '대금': 270,
#  '수수료': 601,
#  '상환': 258,
#  '능력': 182,
#  '대비': 1018,
#  '과도': 93,
#  '하락': 455,
#  '거래': 753,
#  '불이익': 236,
#  '일정': 701,
#  '변제': 145,
#  '의무': 649,
#  '감시': 130,
#  '일광': 544,
#  '유림': 61,
#  '노르웨이숲': 191,
#  '포레': 328,
#  '신도시': 567,
#  '끝판': 84,
#  '등장': 32,
#  '남': 374,
#  '때': 1809,
#  '면적': 319,
#  '전용': 1626,
#  '단지': 2494,
#  '세대': 3678,
#  '조경': 110,
#  '하이': 407,
#  '앤드': 38,
#  '급': 489,
#  '커뮤니티': 497,
#  '리딩': 89,
#  '탄생': 50,
#  '찾기': 124,
#  '대형': 484,
#  '평형': 944,
#  '보유': 821,
#  '타입': 1219,
#  '광초': 40,
#  '동향': 41,
#  '주력': 36,
#  '배치': 85,
#  '일광역': 99,
#  '도보': 1046,
#  '권': 2010,
#  '물산': 100,
#  '시설': 681,
#  '지하': 899,
#  '층': 4817,
#  '지상': 645,
#  '호실': 455,
#  '담당자': 1060,
#  '안창': 8,
#  '팀': 1127,
#  '연락처': 273,
#  '변지영': 4,
#  '채널': 1042,
#  '명': 4658,
#  '돌파': 271,
#  '짐': 599,
#  '뉴': 582,
#  '단독': 5498,
#  '당첨': 1294,
#  '적립금': 658,
#  '추첨': 2962,
#  '아래': 1957,
#  '메세지': 669,
#  '일자': 699,
#  '동의': 3717,
#  '웰': 866,
#  '라이프': 1115,
#  '본사': 868,
#  '쇼핑몰': 425,
#  '에스티': 97,
#  '로더': 86,
#  '방송': 3828,
#  '햇빛': 9,
#  '날씨': 337,
#  '루틴': 19,
#  '피부': 682,
#  '즉각': 23,
#  '진정': 196,
#  '도움': 523,
#  '갈색': 89,
#  '레스큐': 2,
#  '솔루션': 101,
#  '입장': 506,
#  '데이': 703,
#  '디럭스': 131,
#  '대별': 1487,
#  '파운데이션': 102,
#  '브러쉬': 34,
#  '리뷰': 1501,
#  '통해': 1767,
#  '퓨어': 407,
#  '컬러': 271,
#  '립스틱': 43,
#  '레벨': 26,
#  '어스': 59,
#  '파스텔': 4,
#  '오픈': 2503,
#  '국민카드': 105,
#  '그': 542,
#  '닥스': 151,
#  '전원': 1300,
#  '케이스': 2474,
#  '포멜카멜레': 1,
#  '정': 2624,
#  '임': 540,
#  '플라자': 787,
#  '수원': 390,
#  '초대장': 126,
#  '장르': 391,
#  '단일': 935,
#  '웰컴': 394,
#  '첫': 802,
#  '캐시': 886,
#  '청구': 451,
#  '상기': 287,
#  '점내': 136,
#  '지물': 397,
#  '더욱': 388,
#  '데스크': 760,
#  ...}

# %%
from PIL import Image   # 이미지 파일 로드용

wordcloud = WordCloud(
    width = 800,    
    height = 600,    
    background_color='white',
    font_path= 'C:/Windows/Fonts/gulim.ttc', 
    mask = np.array(Image.open('alphaca.png'))
).generate_from_frequencies(word_count)

plt.imshow(wordcloud)   # 워드클라우드 이미지 표시
plt.axis('off')
plt.show()              # 화면 출력

# %%
from PIL import  Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

img = Image.open('alphaca.png').convert('RGBA')     # alphaca.png 파일을 RGBA(투명도 포함)으로 로드
alpha = np.array(img)[:,:,3]                        # 알파 채널만 추출 (0=투명, 255불투명)

mask = np.where(alpha >0 , 255, 0).astype(np.uint8) # 불투명(강아지) 영역 = 255, 투명(배경) 영역 = 0 이진 마스크 생성
mask = 255 - mask                                   # 마스크 반전(배경/강아지 영역이 반대로 적용될 때 사용)


wordcloud = WordCloud(
    width = 800,    
    height = 600,    
    background_color='white',
    font_path= 'C:/Windows/Fonts/gulim.ttc', 
    mask = mask                                     # 단어를 채울 영역(마스크)
).generate_from_frequencies(word_count)

plt.imshow(wordcloud)                                # 워드클라우드 이미지 표시
plt.axis('off')
plt.show()                                           # 화면 출력
